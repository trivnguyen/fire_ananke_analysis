# %%
import os
import h5py

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
gal = 'm12i_res7100'
N = 20

for i in range(N):
    with h5py.File(f'orbit_int/{gal}/i{i}_N{N}.hdf5', 'r') as f:
        peris = f['pericenters'][:]
        apos = f['apocenters'][:]
        id_stars = f['id_stars'][:]

        print(peris, apos)
        print(len(peris), len(apos))
# Out:
# [ 0.70087534  0.117672    0.4191995  ...  7.6897774   6.814103
#  13.809622  ] [ 6.4280148  2.2411556  2.1190906 ... 42.119373  45.872147  38.860477 ]
# 8666 8666
# [14.882208  14.953424  12.925259  ...  2.8024054  1.8473321  9.228971 ] [41.013744 35.559044 41.678444 ... 29.136253 32.083286 38.773903]
# 8667 8667
# [ 6.14749    4.4560895  3.0620604 ...  2.3090706 12.999239   3.795727 ] [24.266582 39.51448  20.407743 ... 25.984795 38.609104 39.24921 ]
# 8666 8666
# [ 6.983698   6.4769096  4.7345676 ...  2.8668191 12.397049   5.5406127] [34.908833 21.474747 21.339277 ... 32.602585 28.066437 19.69925 ]
# 8667 8667
# [4.4077034 4.982672  4.1854696 ... 1.1642747 5.664684  4.083594 ] [33.87891  18.32645  20.901512 ... 11.76078  29.05124  21.92797 ]
# 8667 8667
# [6.4182787 1.6678967 2.866448  ... 0.5309388 1.6357785 3.0119328] [30.819609  8.003115 24.689013 ... 13.121865 16.046652 12.592464]
# 8666 8666
# ...

# %%
plt.scatter(peris, apos)
plt.show()

# %%
# Out:
# array([ 0.70087534,  0.117672  ,  0.4191995 , ...,  7.6897774 ,
#         6.814103  , 13.809622  ], dtype=float32)
